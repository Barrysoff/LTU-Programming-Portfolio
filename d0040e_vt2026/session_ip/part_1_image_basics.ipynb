# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ----------------------
# Read and display image
# ----------------------

# %%
image_in = cv2.imread("/workspaces/LTU-Programming-Portfolio/d0040e_vt2026/session_ip/Assignment 2 Image Processing/flowers_color.png")
image_color = cv2.cvtColor(image_in, cv2.COLOR_BGR2RGB)
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ----------------------
# Display image, Color
# ----------------------

# %%
plt.figure(figsize=(6,6))
plt.imshow(image_color)
plt.title("Color Image")
plt.axis("off")
plt.show()

# %% [markdown]
# ----------------------
# Display image, Gray
# ----------------------

# %%
plt.figure(figsize=(6,6))
plt.imshow(image_gray, cmap="gray", vmin=0, vmax=255)
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %% [markdown]
# ----------------------
# Understanding Image arrays and pixels (Intensity Values)
# ----------------------

# %% [markdown]
# Image size

# %%
height, width = image_gray.shape
print("Gray Image")
print(height, width)

height, width, planes = image_color.shape
print("Color Image")
print(height, width, planes)
# Out:
# Gray Image
# 370 511
# Color Image
# 370 511 3

# %%
print(image_gray[0:2, 0:5])
# Out:
# [[56 58 59 60 61]
#  [58 59 58 61 66]]

# %% [markdown]
# -----
# Accessing pixel values
# -----

# %%
pixel_value = image_gray[height//2, width//2]
print(f"Pixel value at center: {pixel_value}")
# Out:
# Pixel value at center: 112

# %% [markdown]
# -----
# A range of pixels
# -----

# %%
print("Pixel value range")
print(image_gray[0:2, 0:5])
image_cropped = image_gray[0:2,0:5].copy()
# Out:
# Pixel value range
# [[56 58 59 60 61]
#  [58 59 58 61 66]]

# %% [markdown]
# -----
# Display image subset
# -----

# %%
plt.figure(figsize=(6,6))
plt.imshow(image_gray[0:2,0:5], cmap="gray", vmin=0, vmax=255)
plt.title("Grayscale Image")
plt.axis("off")
plt.show()
